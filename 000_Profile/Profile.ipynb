# %% [markdown]
# # Engr. MUHAMMAD OSAID BIN SHAKOOR
#
# Welcome to my professional profile! Feel free to connect with me and explore my work through the following links:
#
# - **Kaggle Profile:** [![Kaggle](https://img.shields.io/badge/Kaggle-20BEFF.svg?&style=flat&logo=Kaggle&logoColor=white "Kaggle Profile")](https://www.kaggle.com/mosaidjutt)
# - **LinkedIn:** [![LinkedIn](https://img.shields.io/badge/LinkedIn-0077B5.svg?&style=flat&logo=linkedin&logoColor=white "Connect on LinkedIn")](https://www.linkedin.com/in/m-osaid)
# - **YouTube Channel:** [![YouTube](https://img.shields.io/badge/YouTube-FF0000.svg?&style=flat&logo=youtube&logoColor=white "Subscribe to my YouTube")](https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl)
# - **Email Me:** [![Gmail](https://img.shields.io/badge/Email-D14836.svg?&style=flat&logo=gmail&logoColor=white "Email Me")](mailto:codingwithosaid@gmail.com)
#
# ### About Me
# I am an engineer and data enthusiast with a passion for solving problems using technology. Check out my channels and work to learn more about my projects and tutorials!

# %% [markdown]
# <h1 style="font-family: 'poppins'; font-weight: bold; color: teal;">👨‍💻Author: Engr. Muhammad Osaid Bin Shakoor</h1>
#
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-teal?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/mosaidjutt)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-teal?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/m-osaid)
#
# [![YouTube](https://img.shields.io/badge/YouTube-Channel-teal?style=for-the-badge&logo=youtube)](https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-teal?style=for-the-badge&logo=email)](mailto:codingwithosaid@gmail.com)

# %% [markdown]
# <h1 style="font-family: 'Arial'; font-weight: bold; color: white;">🛠️ Engr. Muhammad Osaid Bin Shakoor</h1>
#
# <div style="background-color: #333; padding: 20px; border-radius: 10px;">
#     <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none;">
#         <img src="https://img.shields.io/badge/Kaggle-Profile-gray?style=flat-square&logo=kaggle" alt="Kaggle Profile">
#     </a>
#     <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none;">
#         <img src="https://img.shields.io/badge/LinkedIn-Profile-gray?style=flat-square&logo=linkedin" alt="LinkedIn Profile">
#     </a>
#     <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none;">
#         <img src="https://img.shields.io/badge/YouTube-Channel-gray?style=flat-square&logo=youtube" alt="YouTube Channel">
#     </a>
#     <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none;">
#         <img src="https://img.shields.io/badge/Email-Contact%20Me-gray?style=flat-square&logo=email" alt="Email Contact">
#     </a>
# </div>

# %% [markdown]
# <h1 style="font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; color: #FFFFFF; background-color: #1A1A1A; padding: 10px; border-radius: 8px;">Engr. Muhammad Osaid Bin Shakoor</h1>
#
# <p style="font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 16px; color: #DDDDDD; margin-top: 0;">
#     Connect with me on professional and social platforms:
# </p>
#
# <div style="margin-top: 10px;">
#     <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none; color: #FFFFFF; background-color: #0077B5; padding: 8px 16px; border-radius: 4px; display: inline-block; margin-right: 10px;">Kaggle</a>
#     <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none; color: #FFFFFF; background-color: #0077B5; padding: 8px 16px; border-radius: 4px; display: inline-block; margin-right: 10px;">LinkedIn</a>
#     <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none; color: #FFFFFF; background-color: #FF0000; padding: 8px 16px; border-radius: 4px; display: inline-block; margin-right: 10px;">YouTube</a>
#     <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none; color: #FFFFFF; background-color: #505050; padding: 8px 16px; border-radius: 4px; display: inline-block;">Email</a>
# </div>

# %% [markdown]
# <h1 style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; font-weight: bold; color: #4A90E2; margin-bottom: 10px;">Engr. Muhammad Osaid Bin Shakoor</h1>
#
# <p style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; font-size: 16px; color: #333333;">Explore my work and connect with me on professional and social platforms:</p>
#
# <div style="margin-top: 20px;">
#     <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none; background-color: #20BEFF; color: white; padding: 10px 15px; border-radius: 5px; margin-right: 10px; display: inline-block;">Kaggle</a>
#     <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none; background-color: #0077B5; color: white; padding: 10px 15px; border-radius: 5px; margin-right: 10px; display: inline-block;">LinkedIn</a>
#     <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none; background-color: #FF0000; color: white; padding: 10px 15px; border-radius: 5px; margin-right: 10px; display: inline-block;">YouTube</a>
#     <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none; background-color: #4A90E2; color: white; padding: 10px 15px; border-radius: 5px; display: inline-block;">Email</a>
# </div>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; max-width: 400px; border: 1px solid #CCCCCC; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px #AAAAAA;">
#     <div style="background-color: #2E86C1; color: white; padding: 16px; text-align: center;">
#         <h1 style="margin: 0; font-size: 24px;">Engr. Muhammad Osaid Bin Shakoor</h1>
#     </div>
#     <div style="padding: 20px; background-color: white; color: #333;">
#         <p style="font-size: 16px; margin: 10px 0;">Connect with me and explore my work on various platforms.</p>
#         <div style="text-align: center;">
#             <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none; background-color: #3498DB; color: white; padding: 8px 12px; border-radius: 4px; display: inline-block; margin: 5px;">Kaggle</a>
#             <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none; background-color: #0077B5; color: white; padding: 8px 12px; border-radius: 4px; display: inline-block; margin: 5px;">LinkedIn</a>
#             <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none; background-color: #E74C3C; color: white; padding: 8px 12px; border-radius: 4px; display: inline-block; margin: 5px;">YouTube</a>
#             <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none; background-color: #95A5A6; color: white; padding: 8px 12px; border-radius: 4px; display: inline-block; margin: 5px;">Email</a>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: 'Calibri', sans-serif; background-color: #292929; padding: 20px; border-radius: 10px; color: #FFFFFF; text-align: center; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);">
#     <h2 style="color: #4CAF50;">Engr. Muhammad Osaid Bin Shakoor</h2>
#     <p>Connect with me on my professional and social platforms:</p>
#     <div style="margin-top: 20px;">
#         <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none; color: #FFFFFF; background-color: #20C997; padding: 10px 20px; border-radius: 5px; margin: 10px;">Kaggle</a>
#         <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none; color: #FFFFFF; background-color: #007BFF; padding: 10px 20px; border-radius: 5px; margin: 10px;">LinkedIn</a>
#         <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none; color: #FFFFFF; background-color: #FF4B4B; padding: 10px 20px; border-radius: 5px; margin: 10px;">YouTube</a>
#         <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none; color: #FFFFFF; background-color: #6C757D; padding: 10px 20px; border-radius: 5px; margin: 10px;">Email</a>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: 'Lato', sans-serif; max-width: 600px; margin: auto; overflow: hidden; border-radius: 12px; background: linear-gradient(135deg, #6a11cb 0%, #2575fc 100%); box-shadow: 0 8px 30px rgba(0, 0, 0, 0.12);">
#     <div style="padding: 20px; text-align: center; color: #ffffff;">
#         <h1 style="font-size: 28px; margin: 0;">Engr. Muhammad Osaid Bin Shakoor</h1>
#         <p style="font-size: 16px; font-weight: 300; margin-top: 5px; margin-bottom: 20px;">Innovator | Educator | Tech Enthusiast</p>
#     </div>
#     <div style="background-color: rgba(255, 255, 255, 0.1); padding: 15px; display: flex; justify-content: space-around;">
#         <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none; color: #ffffff; background-color: transparent; border: 2px solid #ffffff; padding: 10px; border-radius: 50%; transition: background-color 0.3s, color 0.3s;">
#             <img src="https://img.icons8.com/ios-filled/50/ffffff/kaggle.png" style="width: 30px; height: 30px;">
#         </a>
#         <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none; color: #ffffff; background-color: transparent; border: 2px solid #ffffff; padding: 10px; border-radius: 50%; transition: background-color 0.3s, color 0.3s;">
#             <img src="https://img.icons8.com/ios-filled/50/ffffff/linkedin.png" style="width: 30px; height: 30px;">
#         </a>
#         <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none; color: #ffffff; background-color: transparent; border: 2px solid #ffffff; padding: 10px; border-radius: 50%; transition: background-color 0.3s, color 0.3s;">
#             <img src="https://img.icons8.com/ios-filled/50/ffffff/youtube-play.png" style="width: 30px; height: 30px;">
#         </a>
#         <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none; color: #ffffff; background-color: transparent; border: 2px solid #ffffff; padding: 10px; border-radius: 50%; transition: background-color 0.3s, color 0.3s;">
#             <img src="https://img.icons8.com/ios-filled/50/ffffff/email.png" style="width: 30px; height: 30px;">
#         </a>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: 'Roboto', sans-serif; max-width: 700px; margin: auto; overflow: hidden; border-radius: 12px; background: linear-gradient(135deg, #1c92d2 0%, #f2fcfe 100%); box-shadow: 0 8px 30px rgba(0, 0, 0, 0.12);">
#     <div style="padding: 20px; text-align: center; color: #333;">
#         <h2 style="font-size: 24px; margin: 0; color: #333;">Author Engr. Muhammad Osaid Bin Shakoor</h2>
#         <p style="font-size: 16px; margin-top: 5px; margin-bottom: 20px; color: #555;">Innovator | Educator | Tech Enthusiast</p>
#     </div>
#     <div style="padding: 15px; display: flex; justify-content: space-around; background-color: #ffffff;">
#         <div>
#             <p style="text-align: center; margin: 0; color: #333;">Kaggle</p>
#             <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none;">
#                 <div style="border: 2px solid #0e76a8; color: #0e76a8; padding: 10px; border-radius: 50%; transition: transform 0.3s;">
#                     <img src="https://via.placeholder.com/30x30/0e76a8/ffffff?text=K" style="width: 30px; height: 30px;">
#                 </div>
#             </a>
#         </div>
#         <div>
#             <p style="text-align: center; margin: 0; color: #333;">LinkedIn</p>
#             <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none;">
#                 <div style="border: 2px solid #0072b1; color: #0072b1; padding: 10px; border-radius: 50%; transition: transform 0.3s;">
#                     <img src="https://via.placeholder.com/30x30/0072b1/ffffff?text=L" style="width: 30px; height: 30px;">
#                 </div>
#             </a>
#         </div>
#         <div>
#             <p style="text-align: center; margin: 0; color: #333;">YouTube</p>
#             <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none;">
#                 <div style="border: 2px solid #c4302b; color: #c4302b; padding: 10px; border-radius: 50%; transition: transform 0.3s;">
#                     <img src="https://via.placeholder.com/30x30/c4302b/ffffff?text=Y" style="width: 30px; height: 30px;">
#                 </div>
#             </a>
#         </div>
#         <div>
#             <p style="text-align: center; margin: 0; color: #333;">Email</p>
#             <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none;">
#                 <div style="border: 2px solid #666666; color: #666; padding: 10px; border-radius: 50%; transition: transform 0.3s;">
#                     <img src="https://via.placeholder.com/30x30/666666/ffffff?text=E" style="width: 30px; height: 30px;">
#                 </div>
#             </a>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: 'Montserrat', sans-serif; max-width: 800px; margin: 20px auto; padding: 20px; background: #ffffff; border-radius: 16px; box-shadow: 0 10px 20px rgba(0,0,0,0.1);">
#     <div style="background: #2b5876; background: -webkit-linear-gradient(to right, #4e4376, #2b5876); background: linear-gradient(to right, #4e4376, #2b5876); padding: 20px; border-top-left-radius: 16px; border-top-right-radius: 16px; color: white;">
#         <h2 style="font-size: 30px; margin: 0; text-align: center;">Author Engr. Muhammad Osaid Bin Shakoor</h2>
#         <p style="font-size: 18px; margin: 8px 0 0 0; text-align: center;">Innovator | Educator | Tech Enthusiast</p>
#     </div>
#     <div style="padding: 20px; display: grid; grid-template-columns: repeat(4, 1fr); gap: 10px; text-align: center;">
#         <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none;">
#             <div style="padding: 15px; border: 2px solid #11998e; color: #11998e; border-radius: 8px; transition: all 0.3s ease;">
#                 <p style="margin: 0; font-size: 20px;">Kaggle</p>
#                 <div style="font-size: 50px; line-height: 1;">🔗</div>
#             </div>
#         </a>
#         <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none;">
#             <div style="padding: 15px; border: 2px solid #0e76a8; color: #0e76a8; border-radius: 8px; transition: all 0.3s ease;">
#                 <p style="margin: 0; font-size: 20px;">LinkedIn</p>
#                 <div style="font-size: 50px; line-height: 1;">🔗</div>
#             </div>
#         </a>
#         <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none;">
#             <div style="padding: 15px; border: 2px solid #c4302b; color: #c4302b; border-radius: 8px; transition: all 0.3s ease;">
#                 <p style="margin: 0; font-size: 20px;">YouTube</p>
#                 <div style="font-size: 50px; line-height: 1;">▶️</div>
#             </div>
#         </a>
#         <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none;">
#             <div style="padding: 15px; border: 2px solid #333333; color: #333; border-radius: 8px; transition: all 0.3s ease;">
#                 <p style="margin: 0; font-size: 20px;">Email</p>
#                 <div style="font-size: 50px; line-height: 1;">✉️</div>
#             </div>
#         </a>
#     </div>
# </div>

# %% [markdown]
# <div style="font-family: 'Montserrat', sans-serif; max-width: 800px; margin: 20px auto; padding: 20px; background: #ffffff; border-radius: 16px; box-shadow: 0 10px 20px rgba(0,0,0,0.1);">
#     <div style="background: #33495f; padding: 20px; border-top-left-radius: 16px; border-top-right-radius: 16px; color: white; text-align: center;">
#         <h2 style="font-size: 30px; margin: 0; font-style: italic;"><span style="font-style: normal; font-weight: normal;">Author:</span> ENGR. MUHAMMAD OSAID BIN SHAKOOR</h2>
#     </div>
#     <div style="padding: 20px; display: grid; grid-template-columns: repeat(4, 1fr); gap: 10px; text-align: center;">
#         <div>
#             <img src="https://via.placeholder.com/50x50/11998e/ffffff?text=K" alt="Kaggle" style="width: 50px; height: 50px;">
#             <p style="margin: 5px 0; font-size: 18px; font-weight: bold;">KAGGLE</p>
#             <a href="https://www.kaggle.com/mosaidjutt" style="text-decoration: none;">
#                 <button style="padding: 10px 15px; border: none; border-radius: 8px; background-color: #11998e; color: white; cursor: pointer;">Profile</button>
#             </a>
#         </div>
#         <div>
#             <img src="https://via.placeholder.com/50x50/0e76a8/ffffff?text=L" alt="LinkedIn" style="width: 50px; height: 50px;">
#             <p style="margin: 5px 0; font-size: 18px; font-weight: bold;">LINKEDIN</p>
#             <a href="https://www.linkedin.com/in/m-osaid" style="text-decoration: none;">
#                 <button style="padding: 10px 15px; border: none; border-radius: 8px; background-color: #0e76a8; color: white; cursor: pointer;">Profile</button>
#             </a>
#         </div>
#         <div>
#             <img src="https://via.placeholder.com/50x50/c4302b/ffffff?text=Y" alt="YouTube" style="width: 50px; height: 50px;">
#             <p style="margin: 5px 0; font-size: 18px; font-weight: bold;">YOUTUBE</p>
#             <a href="https://youtube.com/@CodingWithOsaid-ng2wt?si=1BsvQpk_5HIspKvl" style="text-decoration: none;">
#                 <button style="padding: 10px 15px; border: none; border-radius: 8px; background-color: #c4302b; color: white; cursor: pointer;">Profile</button>
#             </a>
#         </div>
#         <div>
#             <img src="https://via.placeholder.com/50x50/333333/ffffff?text=E" alt="Email" style="width: 50px; height: 50px;">
#             <p style="margin: 5px 0; font-size: 18px; font-weight: bold;">EMAIL</p>
#             <a href="mailto:codingwithosaid@gmail.com" style="text-decoration: none;">
#                 <button style="padding: 10px 15px; border: none; border-radius: 8px; background-color: #333333; color: white; cursor: pointer;">Contact</button>
#             </a>
#         </div>
#     </div>
# </div>
